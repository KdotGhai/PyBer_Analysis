# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)



plt.show()

# %%
###### Create the plot with ax.plt()  ##This is creating a Tuple(data that cannot be changed and uses much less memory)

## Here we're asking to produce a figure just like above but it has no parameter for X and Y axis
fig, ax = plt.subplots()

###ax.plt() will import the data that will be assigned to X and Y axis
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plot()   ###Alternative to using subplot,fig, and ax
## Set Size  of Figure with figsize inside of plt.figure(figsize(width,height))
fig = plt.figure(figsize=(12,12))  #will generate blank chart/figure
ax = fig.add_subplot() #is appending data needed to fill in chart/figure(currently empty)



#plt.show()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()  ###Another Alternative for quickly making chart with parameters
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#### Set Size of plot chart
plt.rcParams['figure.figsize'] = [12, 12]

# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

plt.show()

# %%
### Amending Chart above to have grid, colors = blue, markers ="*"


# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

plt.rcParams['figure.figsize'] = [20, 20]

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
########Skill excercise

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=3, label='Boston')

plt.rcParams['figure.figsize'] = [8, 8]

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
###### MOVING ONTO BAR CHARTS

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
### To annotate/ammened bar graph we use same methods as before 
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Now creating Bar Chart horizontally

# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)

# To invert the y-axis to have the months in ascending order, use the gca() method. The gca() method means "get current axes." 
# We can chain the gca() method to the invert_yaxis() method by using gca().invert_yaxis(), as shown
plt.gca().invert_yaxis()

# %%
#### Skill excercise for Bar H

# %%
### To annotate/ammened bar graph we use same methods as before 
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()
### invert data order for y-axis (So that January is on top and going down)
plt.gca().invert_yaxis()

# %%
### Now to create Bar chart as Tuple() form (Uses less memory and data cannot be changed)

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="k", label='New York')
ax.grid()
ax.legend()

# %%
### Now do the Same for horizontal bar graph

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
### Skill excercise
# Change the bar color to cyan.

#Add a legend for the city of Chicago.

#Add a title and axes labels.

#Switch the axis so that the Fare($) data is on the x-axis.

#Invert the y-axis data.

# %%
#create graph
fig, ax = plt.subplots()
ax.barh(x_axis,y_axis, color ="cyan", label = "Chicago")
### label axis and title
plt.title("PyBer by Month")
plt.ylabel("Months")
plt.xlabel("Fare($)")
## inverse y-axis data
plt.gca().invert_yaxis()
## plt.gca().invert_xaxis()  if you wanted to inverse x axis, inverse x_axis, inverse x-axis
## Shows legend(such as labels)
ax.legend()

# %%
#### Moving onto scatter plots

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.scatter(x_axis, y_axis )
#Alternative but not desired method: plt.plot(x_axis, y_axis, 'o')
# the 'o' is simply an argument to remove the lines and only show plot points

# %%
###### Skill Excercise
#Change the color of the markers to red.

#Add a legend for the city of Chicago.

#Add a title and axes labels.

#Switch the axis so that the Fare($) data is on the x-axis.

#Add a limit for the x-axis data.

#Invert the y-axis so that January is at the top.

# %%
#create graph
plt.scatter(y_axis, x_axis,  color = "red",label= "Chicago" , s = 50)
#Set labels
plt.title("PyBer by Month")
plt.ylabel("Months")
plt.xlabel("Fare($)")
#inverse data for y-axis
plt.gca().invert_yaxis()
#show legend
plt.legend()

# %%
#### Manipulate size of data points based on axis data

plt.scatter(x_axis, y_axis, s=y_axis)

#The data points change in size but its not clean or presentable

# %%
### We're going to increase the size of y values (Still a scatter plot but now is know as Bubble Chart)
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

### Then display again the data with the new  y_axis_larger which is simply 3 times of y_axis original values
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
### Instead of using For/while loops python is capable of recognizing patterns thus we can use list comprehension

plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# We produced the same data results as above

# %%
### Now to create (Obejct orientated interface) or tuple() based scatter plot

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s = y_axis)

# %%
#### skill excercise

#Change the color of the markers to sky blue.

#Change the size of the markers to 5 times each data point.

#Make the color 20% transparent.

#Add a black edge color to the circles.

#Make the linewidth of the circles 2 points.

#Add a legend for the city of Boston.

#Add a title.

#Switch the axis so that the Fare($) data is on the x-axis.

#Add a limit for the x-axis data.

#Invert the y-axis so that January is at the top.

# %%
# (Still a scatter plot but now is know as Bubble Chart)
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis,  color = 'xkcd:sky blue' ,  alpha= .8 , edgecolors= "black", linewidths= 2
           , label= "Boston",s = [i * 5 for i in y_axis])

#set labels
plt.title("PyBer by Month", weight = 'bold', fontsize=25)

plt.ylabel("Months", weight = 'bold', fontsize=20) #ADjust fontsize and bold xlabel
plt.xlabel("Fare($)", weight = 'bold', fontsize=20)


#inverse data for y-axis
plt.gca().invert_yaxis()
#set xlim to 50
ax.set_xlim(0, 50)
#show legend
ax.legend()

# %%
### Moving onto Pie Charts

# %%
plt.subplots(figsize=(10, 8))
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
plt.subplots(figsize=(10, 10))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0.1)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%', textprops={'fontsize': 12})
plt.show()

## Set fontsize of pie chart as shown in code above in this cell

# %%
### We can even set custom colors to the pie chart

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(10,10))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%',
    textprops={'fontsize': 12})

plt.show()

# %%
####Create a Pie Chart Using the Object-Oriented Interface or Tuple() based

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#Skill drill

#Add a percentage to one decimal place to each wedge of the pie.

#Increase the figure size to 8x8.

#Explode the two highest percentage months.

#Add a shadow.

#Add a start angle so that January is at the top.

#Reverse the order so that the month order is in a clockwise direction.

#Add new colors of your own choosing or use the colors from the previous pie chart.

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

fig, ax = plt.subplots(figsize=(10,10))
ax.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%',
    counterclock = False,
    startangle= 100,
    textprops={'fontsize': 12})

plt.show()

# %%
### Chart Extras

# %%
### Error Bars to line Chart

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# %matplotlib inline

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
### let's add error bars and a capsize using the object-oriented approach.

fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
## Add Error Bars to a Bar Chart

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
### let's add error bars and a capsize using the object-oriented approach.

fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
## Change the Major Ticks

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

plt.show()

# %%
### create the same graph using the object-oriented approach

fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()

# %%
### Add Minor Ticks

from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(10, 10))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
